# %%
# using python kernel 3.13.2

# %%
import os
import json
import subprocess
import random
import numpy as np
from pathlib import Path
from datetime import datetime, timezone
from itertools import product, combinations
from collections import defaultdict
import sys
import time

# %% [markdown]
# ## Configuration

# %%
# Seed for reproducibility
RANDOM_SEED = 2084
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# Project paths
ROOT = Path('S:/UVG/LOCKIN/emotune/workspace')
TRANSFORMER = ROOT / 'transformer'
EXP = ROOT / 'exp/eval_run_v7_01'
DATASET_ROOT = Path('S:/UVG/LOCKIN/emotune/dataset')

# Models to evaluate
MODELS = [
    {
        'name': 'scratch',
        'load_ckt': 'checkpoints',
        'load_ckt_loss': '8', # Mejor modelo propio
        'load_dict': 'train_dictionary.pkl',
        'word2event_path': DATASET_ROOT / 'word2event_scratch.json',
    },
    # {
    #     'name': 'pretrained',
    #     'load_ckt': 'checkpoints',
    #     'load_ckt_loss': 'pre',
    #     'load_dict': 'dictionary.pkl',
    #     'word2event_path': ROOT / 'word2event.json',
    # },
]

# ALL inference modes to compare
# Note: inference-normal removed as it's functionally identical to inference-primed
MODES = [
    'inference-deterministic',
    'inference-primed',
    'inference-forced'
]

# Tokens of interest for conditioning (NOTE-level tokens)
TOKENS_OF_INTEREST = ['duration', 'velocity']

# Emotions to evaluate (stratified)
EMOTIONS = [1, 2, 3, 4]
KEYS = ['A:maj', 'C:maj', 'E:min']  # Only for scratch model

# Base generation parameters
COMMON_ARGS = {
    'task_type': '4-cls',
    'num_songs': 1,  # samples per combination
    'save_tokens_json': 1,
    'generation_timeout': 30
}

# How many values to sample per token for condition grid
MAX_VALUES_PER_TOKEN = {
    'duration': 2,
    'velocity': 2,
}

# Condition set sizes to test (e.g., [1, 2] = single token and pairs)
CONDITION_SET_SIZES = [1]  # Start with single token conditioning

# %% [markdown]
# ## HELPER FUNCTIONS

# %%
def load_json(path):
    with open(path, 'r', encoding='utf-8') as f:
        return json.load(f)

def build_candidates_from_word2event(word2event):
    """Build condition candidates for tokens of interest"""
    candidates = {}
    for token in TOKENS_OF_INTEREST:
        if token not in word2event:
            continue
        items = word2event[token]
        cands = []
        for idx_str, label in items.items():
            # Skip sentinel values
            if str(idx_str) == '0' or label == 'CONTI' or label == 'Note_Duration_0':
                continue
            if isinstance(label, str):
                cands.append(label)
        if cands:
            cands.sort()  # Sort for consistency
            candidates[token] = cands
    return candidates

def sample_values_stratified(vals, n, seed_offset=0):
    """Sample n values evenly across the range"""
    rng = random.Random(RANDOM_SEED + seed_offset)
    if len(vals) <= n:
        return vals
    # Sample evenly across the range
    indices = [int(i * len(vals) / n) for i in range(n)]
    return [vals[i] for i in indices]

def build_condition_grid(model_name, candidates_map):
    """Build grid of condition combinations for a model"""
    token_names = [t for t in TOKENS_OF_INTEREST if t in candidates_map]
    
    # Sample values per token
    token_to_vals = {}
    for i, t in enumerate(token_names):
        vals = candidates_map[t]
        n = MAX_VALUES_PER_TOKEN.get(t, 3)
        token_to_vals[t] = sample_values_stratified(vals, n, seed_offset=i)
    
    # Generate combinations
    grid = []  # list of (token_subset, list_of_condition_dicts)
    for k in CONDITION_SET_SIZES:
        for subset in combinations(token_names, k):
            grids_for_subset = [token_to_vals[t] for t in subset]
            combinations_list = []
            for combo in product(*grids_for_subset):
                cond_dict = {t: v for t, v in zip(subset, combo)}
                combinations_list.append(cond_dict)
            grid.append((subset, combinations_list))
    
    return grid

def build_cmd(mode, model, emotion_tag, conditions=None, force_tokens=None, out_dir=None, key_tag=None):
    """
    Build command to run main_cp.py.
    
    Args:
        mode: inference mode string
        model: dict with model configuration
        emotion_tag: int, emotion category
        conditions: optional dict for primed mode
        force_tokens: optional dict for forced mode
        out_dir: output directory path
        key_tag: optional key tag (only for scratch model)
    """
    args = []
    def add(k, v):
        args.extend([f'--{k}', str(v)])

    add('data_root', str(DATASET_ROOT / 'co-representation'))
    add('exp_path', str(EXP))
    add('mode', mode)
    add('task_type', COMMON_ARGS['task_type'])
    add('num_songs', COMMON_ARGS['num_songs'])
    add('emo_tag', emotion_tag)
    add('save_tokens_json', COMMON_ARGS['save_tokens_json'])
    add('load_ckt', model['load_ckt'])
    add('load_ckt_loss', model['load_ckt_loss'])
    add('load_dict', model['load_dict'])
    
    # Mode-specific conditioning
    if mode in ['inference-primed', 'inference-deterministic'] and conditions:
        add('conditions', json.dumps(conditions))
    elif mode == 'inference-forced' and force_tokens:
        add('force_tokens', json.dumps(force_tokens))
    
    # Key tag for scratch model only
    if model['name'] == 'scratch' and key_tag:
        add('key_tag', key_tag)
    
    # Output directory
    if out_dir:
        add('out_dir', str(out_dir))
    
    cmd = ["python", str(TRANSFORMER / 'main_cp.py')] + args
    return cmd

# %% [markdown]
# ## MAIN EVALUATION

# %%
# Tiempo de inicio
main_evaluation_start_time = time.time()

# %%
print('=' * 70)
print('COMPREHENSIVE EVALUATION CONFIGURATION')
print('=' * 70)
print(f"Models: {[m['name'] for m in MODELS]}")
print(f"Modes: {MODES}")
print(f"Tokens of interest: {TOKENS_OF_INTEREST}")
print(f"Emotions: {EMOTIONS}")
print(f"Condition set sizes: {CONDITION_SET_SIZES}")
print(f"Random seed: {RANDOM_SEED}")
print('=' * 70)
print()

# Load vocabularies
MODEL_TO_WORD2EVENT = {}
MODEL_TO_CANDIDATES = {}

for m in MODELS:
    name = m['name']
    vocab_path = m.get('word2event_path')
    
    if not vocab_path or not Path(vocab_path).exists():
        print(f"[!] Missing vocab for {name}: {vocab_path}")
        continue
    
    w2e = load_json(vocab_path)
    MODEL_TO_WORD2EVENT[name] = w2e
    MODEL_TO_CANDIDATES[name] = build_candidates_from_word2event(w2e)

# Build condition grids
MODEL_TO_CONDITION_GRID = {}
for m in MODELS:
    name = m['name']
    cands = MODEL_TO_CANDIDATES.get(name, {})
    MODEL_TO_CONDITION_GRID[name] = build_condition_grid(name, cands)

# Calculate total runs
total_runs = 0
for model in MODELS:
    grid = MODEL_TO_CONDITION_GRID.get(model['name'], [])
    keys_count = len(KEYS) if model['name'] == 'scratch' else 1
    for subset, cond_list in grid:
        total_runs += len(cond_list) * len(MODES) * len(EMOTIONS) * keys_count

print(f"Total runs to execute: {total_runs}")
print("=" * 70)
print()

# Main evaluation loop
ALL_RUNS = []
run_idx = 0

for model in MODELS:
    model_name = model['name']
    grid = MODEL_TO_CONDITION_GRID.get(model_name, [])
    
    print(f"{'='*70}")
    print(f"MODEL: {model_name.upper()}")
    print(f"{'='*70}")
    
    for subset, cond_list in grid:
        subset_label = '_'.join(subset) if subset else 'unconditional'
        
        for cond in cond_list:
            # Stringify condition for directory name
            cond_str = '_'.join([f"{k[:3]}{v.split('_')[-1]}" for k, v in cond.items()]) if cond else 'none'
            
            # For scratch model, iterate over keys; for pretrained, use None
            keys_to_test = KEYS if model_name == 'scratch' else [None]
            
            for emotion in EMOTIONS:
                for key in keys_to_test:
                    for mode in MODES:
                        run_idx += 1
                        
                        # Create output directory
                        stamp = datetime.now(timezone.utc).strftime('%Y%m%d-%H%M%S%f')[:19]
                        key_str = f"_key{key.replace(':', '')}" if key else ""
                        out_dir = EXP / f"{model_name}_{mode}_{subset_label}_emo{emotion}{key_str}_{cond_str}_{stamp}"
                        out_dir.mkdir(parents=True, exist_ok=True)
                        
                        # Determine conditioning based on mode
                        conditions = cond if mode in ['inference-primed', 'inference-deterministic'] else None
                        force_tokens = cond if mode in ['inference-forced'] else None
                        
                        # Build and run command
                        cmd = build_cmd(mode, model, emotion, conditions, force_tokens, out_dir, key)
                        
                        key_info = f" | key:{key}" if key else ""
                        print(f"[{run_idx}/{total_runs}] {model_name:12s} | {mode:26s} | emo{emotion}{key_info} | {cond}")
                        
                        try:
                            print('Command:\n', ' '.join(cmd))

                            proc = subprocess.run(cmd, cwd=str(TRANSFORMER), 
                                                capture_output=True, text=True, timeout=300)
                            
                            # Store metadata
                            ALL_RUNS.append({
                                'model': model_name,
                                'mode': mode,
                                'emotion': emotion,
                                'key': key,
                                'subset': list(subset),
                                'conditions': cond,
                                'out_dir': str(out_dir),
                                'returncode': proc.returncode,
                                'stdout': proc.stdout[-2000:],
                                'stderr': proc.stderr[-2000:],
                            })
                            
                            status = "✓" if proc.returncode == 0 else f"✗ (code {proc.returncode})"
                            print(f"  Status: {status}")
                            
                        except subprocess.TimeoutExpired:
                            print(f"  Status: ✗ TIMEOUT")
                            ALL_RUNS.append({
                                'model': model_name,
                                'mode': mode,
                                'emotion': emotion,
                                'key': key,
                                'subset': list(subset),
                                'conditions': cond,
                                'out_dir': str(out_dir),
                                'returncode': -1,
                                'stdout': '',
                                'stderr': 'TIMEOUT',
                            })

print("\n" + "=" * 70)
print(f"EVALUATION COMPLETE: {len(ALL_RUNS)} total runs")
print("=" * 70)

# Summary
success_count = sum(1 for r in ALL_RUNS if r['returncode'] == 0)
print(f"Successful: {success_count}/{len(ALL_RUNS)}")
print(f"Failed: {len(ALL_RUNS) - success_count}/{len(ALL_RUNS)}")
print()

# Save run metadata
runs_file = EXP / 'all_runs_metadata.json'
with open(runs_file, 'w', encoding='utf-8') as f:
    json.dump(ALL_RUNS, f, indent=2)
print(f"Run metadata saved to: {runs_file}")
print()
# Out:
# ======================================================================
# COMPREHENSIVE EVALUATION CONFIGURATION
# ======================================================================
# Models: ['scratch', 'pretrained']
# Modes: ['inference-deterministic', 'inference-primed', 'inference-forced']
# Tokens of interest: ['duration', 'velocity']
# Emotions: [1, 2, 3, 4]
# Condition set sizes: [1]
# Random seed: 2084
# ======================================================================
#
# Total runs to execute: 192
# ======================================================================
#
# ======================================================================
# MODEL: SCRATCH
# ======================================================================
# [1/192] scratch      | inference-deterministic    | emo1 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo1_keyAmaj_dur1080_20251103-0601416989
#   Status: ✓
# [2/192] scratch      | inference-primed           | emo1 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo1_keyAmaj_dur1080_20251103-0602057929
#   Status: ✓
# [3/192] scratch      | inference-forced           | emo1 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo1_keyAmaj_dur1080_20251103-0602219801
#   Status: ✓
# [4/192] scratch      | inference-deterministic    | emo1 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo1_keyCmaj_dur1080_20251103-0603274911
#   Status: ✓
# [5/192] scratch      | inference-primed           | emo1 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo1_keyCmaj_dur1080_20251103-0603397479
#   Status: ✓
# [6/192] scratch      | inference-forced           | emo1 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo1_keyCmaj_dur1080_20251103-0603485553
#   Status: ✓
# [7/192] scratch      | inference-deterministic    | emo1 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo1_keyEmin_dur1080_20251103-0604542479
#   Status: ✓
# [8/192] scratch      | inference-primed           | emo1 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo1_keyEmin_dur1080_20251103-0605043473
#   Status: ✓
# [9/192] scratch      | inference-forced           | emo1 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo1_keyEmin_dur1080_20251103-0605183865
#   Status: ✓
# [10/192] scratch      | inference-deterministic    | emo2 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo2_keyAmaj_dur1080_20251103-0606237108
#   Status: ✓
# [11/192] scratch      | inference-primed           | emo2 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo2_keyAmaj_dur1080_20251103-0606431778
#   Status: ✓
# [12/192] scratch      | inference-forced           | emo2 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo2_keyAmaj_dur1080_20251103-0606576747
#   Status: ✓
# [13/192] scratch      | inference-deterministic    | emo2 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo2_keyCmaj_dur1080_20251103-0608024449
#   Status: ✓
# [14/192] scratch      | inference-primed           | emo2 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo2_keyCmaj_dur1080_20251103-0608259738
#   Status: ✓
# [15/192] scratch      | inference-forced           | emo2 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo2_keyCmaj_dur1080_20251103-0608353401
#   Status: ✓
# [16/192] scratch      | inference-deterministic    | emo2 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo2_keyEmin_dur1080_20251103-0609399410
#   Status: ✓
# [17/192] scratch      | inference-primed           | emo2 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo2_keyEmin_dur1080_20251103-0610102663
#   Status: ✓
# [18/192] scratch      | inference-forced           | emo2 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo2_keyEmin_dur1080_20251103-0610212323
#   Status: ✓
# [19/192] scratch      | inference-deterministic    | emo3 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo3_keyAmaj_dur1080_20251103-0611263828
#   Status: ✓
# [20/192] scratch      | inference-primed           | emo3 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo3_keyAmaj_dur1080_20251103-0611383826
#   Status: ✓
# [21/192] scratch      | inference-forced           | emo3 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo3_keyAmaj_dur1080_20251103-0611476882
#   Status: ✓
# [22/192] scratch      | inference-deterministic    | emo3 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo3_keyCmaj_dur1080_20251103-0612523604
#   Status: ✓
# [23/192] scratch      | inference-primed           | emo3 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo3_keyCmaj_dur1080_20251103-0612598205
#   Status: ✓
# [24/192] scratch      | inference-forced           | emo3 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo3_keyCmaj_dur1080_20251103-0613085035
#   Status: ✓
# [25/192] scratch      | inference-deterministic    | emo3 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo3_keyEmin_dur1080_20251103-0614132467
#   Status: ✓
# [26/192] scratch      | inference-primed           | emo3 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo3_keyEmin_dur1080_20251103-0614235308
#   Status: ✓
# [27/192] scratch      | inference-forced           | emo3 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo3_keyEmin_dur1080_20251103-0614473307
#   Status: ✓
# [28/192] scratch      | inference-deterministic    | emo4 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo4_keyAmaj_dur1080_20251103-0615522920
#   Status: ✓
# [29/192] scratch      | inference-primed           | emo4 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo4_keyAmaj_dur1080_20251103-0616011729
#   Status: ✓
# [30/192] scratch      | inference-forced           | emo4 | key:A:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo4_keyAmaj_dur1080_20251103-0616094229
#   Status: ✓
# [31/192] scratch      | inference-deterministic    | emo4 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo4_keyCmaj_dur1080_20251103-0617141736
#   Status: ✓
# [32/192] scratch      | inference-primed           | emo4 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo4_keyCmaj_dur1080_20251103-0617198559
#   Status: ✓
# [33/192] scratch      | inference-forced           | emo4 | key:C:maj | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo4_keyCmaj_dur1080_20251103-0617266310
#   Status: ✓
# [34/192] scratch      | inference-deterministic    | emo4 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo4_keyEmin_dur1080_20251103-0618313188
#   Status: ✓
# [35/192] scratch      | inference-primed           | emo4 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo4_keyEmin_dur1080_20251103-0618488523
#   Status: ✓
# [36/192] scratch      | inference-forced           | emo4 | key:E:min | {'duration': 'Note_Duration_1080'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1080"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo4_keyEmin_dur1080_20251103-0618570317
#   Status: ✓
# [37/192] scratch      | inference-deterministic    | emo1 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo1_keyAmaj_dur1920_20251103-0620017430
#   Status: ✓
# [38/192] scratch      | inference-primed           | emo1 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo1_keyAmaj_dur1920_20251103-0620127171
#   Status: ✓
# [39/192] scratch      | inference-forced           | emo1 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo1_keyAmaj_dur1920_20251103-0620221058
#   Status: ✓
# [40/192] scratch      | inference-deterministic    | emo1 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo1_keyCmaj_dur1920_20251103-0621267005
#   Status: ✓
# [41/192] scratch      | inference-primed           | emo1 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo1_keyCmaj_dur1920_20251103-0621368806
#   Status: ✓
# [42/192] scratch      | inference-forced           | emo1 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo1_keyCmaj_dur1920_20251103-0621493918
#   Status: ✓
# [43/192] scratch      | inference-deterministic    | emo1 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo1_keyEmin_dur1920_20251103-0622541488
#   Status: ✓
# [44/192] scratch      | inference-primed           | emo1 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo1_keyEmin_dur1920_20251103-0623073875
#   Status: ✓
# [45/192] scratch      | inference-forced           | emo1 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo1_keyEmin_dur1920_20251103-0623185338
#   Status: ✓
# [46/192] scratch      | inference-deterministic    | emo2 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo2_keyAmaj_dur1920_20251103-0624234535
#   Status: ✓
# [47/192] scratch      | inference-primed           | emo2 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo2_keyAmaj_dur1920_20251103-0624331904
#   Status: ✓
# [48/192] scratch      | inference-forced           | emo2 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo2_keyAmaj_dur1920_20251103-0624447896
#   Status: ✓
# [49/192] scratch      | inference-deterministic    | emo2 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo2_keyCmaj_dur1920_20251103-0625495185
#   Status: ✓
# [50/192] scratch      | inference-primed           | emo2 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo2_keyCmaj_dur1920_20251103-0626543237
#   Status: ✓
# [51/192] scratch      | inference-forced           | emo2 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo2_keyCmaj_dur1920_20251103-0627022621
#   Status: ✓
# [52/192] scratch      | inference-deterministic    | emo2 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo2_keyEmin_dur1920_20251103-0628069535
#   Status: ✓
# [53/192] scratch      | inference-primed           | emo2 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo2_keyEmin_dur1920_20251103-0628199926
#   Status: ✓
# [54/192] scratch      | inference-forced           | emo2 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo2_keyEmin_dur1920_20251103-0628281866
#   Status: ✓
# [55/192] scratch      | inference-deterministic    | emo3 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo3_keyAmaj_dur1920_20251103-0629328233
#   Status: ✓
# [56/192] scratch      | inference-primed           | emo3 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo3_keyAmaj_dur1920_20251103-0629401822
#   Status: ✓
# [57/192] scratch      | inference-forced           | emo3 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo3_keyAmaj_dur1920_20251103-0629515606
#   Status: ✓
# [58/192] scratch      | inference-deterministic    | emo3 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo3_keyCmaj_dur1920_20251103-0630562859
#   Status: ✓
# [59/192] scratch      | inference-primed           | emo3 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo3_keyCmaj_dur1920_20251103-0631051430
#   Status: ✓
# [60/192] scratch      | inference-forced           | emo3 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo3_keyCmaj_dur1920_20251103-0631109897
#   Status: ✓
# [61/192] scratch      | inference-deterministic    | emo3 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo3_keyEmin_dur1920_20251103-0632156381
#   Status: ✓
# [62/192] scratch      | inference-primed           | emo3 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo3_keyEmin_dur1920_20251103-0632218087
#   Status: ✓
# [63/192] scratch      | inference-forced           | emo3 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag E:min --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo3_keyEmin_dur1920_20251103-0632290686
#   Status: ✓
# [64/192] scratch      | inference-deterministic    | emo4 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo4_keyAmaj_dur1920_20251103-0633337547
#   Status: ✓
# [65/192] scratch      | inference-primed           | emo4 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo4_keyAmaj_dur1920_20251103-0633416357
#   Status: ✓
# [66/192] scratch      | inference-forced           | emo4 | key:A:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag A:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo4_keyAmaj_dur1920_20251103-0633505251
#   Status: ✓
# [67/192] scratch      | inference-deterministic    | emo4 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-deterministic_duration_emo4_keyCmaj_dur1920_20251103-0634551085
#   Status: ✓
# [68/192] scratch      | inference-primed           | emo4 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --conditions {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-primed_duration_emo4_keyCmaj_dur1920_20251103-0635030745
#   Status: ✓
# [69/192] scratch      | inference-forced           | emo4 | key:C:maj | {'duration': 'Note_Duration_1920'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss 8 --load_dict train_dictionary.pkl --force_tokens {"duration": "Note_Duration_1920"} --key_tag C:maj --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\scratch_inference-forced_duration_emo4_keyCmaj_dur1920_20251103-0635130666
#   Status: ✓
# [70/192] scratch      | inference-deterministic    | emo4 | key:E:min | {'duration': 'Note_Duration_1920'}
# Command:
# ...
#   Status: ✓
# [169/192] pretrained   | inference-deterministic    | emo1 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-deterministic_velocity_emo1_vel100_20251103-0719168806
#   Status: ✓
# [170/192] pretrained   | inference-primed           | emo1 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-primed_velocity_emo1_vel100_20251103-0719301240
#   Status: ✓
# [171/192] pretrained   | inference-forced           | emo1 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --force_tokens {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-forced_velocity_emo1_vel100_20251103-0719390098
#   Status: ✓
# [172/192] pretrained   | inference-deterministic    | emo2 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-deterministic_velocity_emo2_vel100_20251103-0720062052
#   Status: ✓
# [173/192] pretrained   | inference-primed           | emo2 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-primed_velocity_emo2_vel100_20251103-0720157412
#   Status: ✓
# [174/192] pretrained   | inference-forced           | emo2 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --force_tokens {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-forced_velocity_emo2_vel100_20251103-0720261025
#   Status: ✓
# [175/192] pretrained   | inference-deterministic    | emo3 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-deterministic_velocity_emo3_vel100_20251103-0720504176
#   Status: ✓
# [176/192] pretrained   | inference-primed           | emo3 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-primed_velocity_emo3_vel100_20251103-0721006665
#   Status: ✓
# [177/192] pretrained   | inference-forced           | emo3 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --force_tokens {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-forced_velocity_emo3_vel100_20251103-0721112765
#   Status: ✓
# [178/192] pretrained   | inference-deterministic    | emo4 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-deterministic_velocity_emo4_vel100_20251103-0721261527
#   Status: ✓
# [179/192] pretrained   | inference-primed           | emo4 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-primed_velocity_emo4_vel100_20251103-0721344612
#   Status: ✓
# [180/192] pretrained   | inference-forced           | emo4 | {'velocity': 'Note_Velocity_100'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --force_tokens {"velocity": "Note_Velocity_100"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-forced_velocity_emo4_vel100_20251103-0721422517
#   Status: ✓
# [181/192] pretrained   | inference-deterministic    | emo1 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-deterministic_velocity_emo1_vel58_20251103-0722061054
#   Status: ✓
# [182/192] pretrained   | inference-primed           | emo1 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-primed_velocity_emo1_vel58_20251103-0722151821
#   Status: ✓
# [183/192] pretrained   | inference-forced           | emo1 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 1 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --force_tokens {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-forced_velocity_emo1_vel58_20251103-0722226269
#   Status: ✓
# [184/192] pretrained   | inference-deterministic    | emo2 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-deterministic_velocity_emo2_vel58_20251103-0722362818
#   Status: ✓
# [185/192] pretrained   | inference-primed           | emo2 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-primed_velocity_emo2_vel58_20251103-0722448418
#   Status: ✓
# [186/192] pretrained   | inference-forced           | emo2 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 2 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --force_tokens {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-forced_velocity_emo2_vel58_20251103-0722529343
#   Status: ✓
# [187/192] pretrained   | inference-deterministic    | emo3 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-deterministic_velocity_emo3_vel58_20251103-0723012414
#   Status: ✓
# [188/192] pretrained   | inference-primed           | emo3 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-primed_velocity_emo3_vel58_20251103-0723103175
#   Status: ✓
# [189/192] pretrained   | inference-forced           | emo3 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 3 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --force_tokens {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-forced_velocity_emo3_vel58_20251103-0723205511
#   Status: ✓
# [190/192] pretrained   | inference-deterministic    | emo4 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-deterministic --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-deterministic_velocity_emo4_vel58_20251103-0723299172
#   Status: ✓
# [191/192] pretrained   | inference-primed           | emo4 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-primed --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --conditions {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-primed_velocity_emo4_vel58_20251103-0723384544
#   Status: ✓
# [192/192] pretrained   | inference-forced           | emo4 | {'velocity': 'Note_Velocity_58'}
# Command:
#  python S:\UVG\LOCKIN\emotune\workspace\transformer\main_cp.py --data_root S:\UVG\LOCKIN\emotune\dataset\co-representation --exp_path S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01 --mode inference-forced --task_type 4-cls --num_songs 1 --emo_tag 4 --save_tokens_json 1 --load_ckt checkpoints --load_ckt_loss pre --load_dict dictionary.pkl --force_tokens {"velocity": "Note_Velocity_58"} --out_dir S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\pretrained_inference-forced_velocity_emo4_vel58_20251103-0723488408
#   Status: ✓
#
# ======================================================================
# EVALUATION COMPLETE: 192 total runs
# ======================================================================
# Successful: 192/192
# Failed: 0/192
#
# Run metadata saved to: S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\all_runs_metadata.json

# %%
# Tiempo de fin
main_evaluation_end_time = time.time()
print(f"Tiempo total de evaluación: {main_evaluation_end_time - main_evaluation_start_time:.2f} segundos")
# Out:
# Tiempo total de evaluación: 4938.34 segundos

# %% [markdown]
# ## ADHERENCE ANALYSIS

# %%
# Tiempo de inicio
adherence_analysis_start_time = time.time()

# %%
print("=" * 70)
print("ADHERENCE ANALYSIS (with distance metrics)")
print("=" * 70)
print()

# Import the updated adherence function
sys.path.insert(0, str(TRANSFORMER))
from analyze_adherence import compute_adherence
from analyze_emotion_key import compute_emotion_key_adherence

REPORTS = []
EMOTION_KEY_REPORTS = []

# Token adherence analysis
# Note: Skip token adherence for inference-forced mode since forced tokens
# will always be 100% adherent by design (tautological measurement).
# We still compute emotion/key adherence for forced mode to assess whether
# constraining note-level tokens disrupts higher-level musical structure.
for run in ALL_RUNS:
    if run['returncode'] != 0:
        continue
    
    # Skip token adherence for forced mode (measure only emotion/key)
    if run['mode'] == 'inference-forced':
        continue
    
    out_dir = run['out_dir']
    model_name = run['model']
    
    # Find metadata files
    metas = [f for f in os.listdir(out_dir) if f.endswith('.meta.json')]
    if not metas:
        continue
    
    # Get word2event for this model
    word2event = MODEL_TO_WORD2EVENT.get(model_name)
    
    per_file = []
    for mf in metas:
        meta_path = os.path.join(out_dir, mf)
        try:
            with open(meta_path, 'r', encoding='utf-8') as f:
                meta = json.load(f)
            
            tokens = np.load(meta['paths']['npy'])
            conditions = meta.get('conditions_indices') or meta.get('force_indices') or {}
            token_order = meta.get('vocab_order') or []
            
            # Compute adherence with distance metrics
            adherence = compute_adherence(tokens, conditions, token_order, word2event)
            
            per_file.append({
                'meta': meta_path,
                'adherence': adherence,
                'num_tokens': tokens.shape[0]
            })
            
        except Exception as e:
            print(f"  [ERROR] {mf}: {e}")
            continue
    
    if per_file:
        REPORTS.append({'run': run, 'files': per_file})

print(f"Analyzed token adherence for {len(REPORTS)} successful runs")
print()

# Emotion and key adherence analysis
print("=" * 70)
print("EMOTION AND KEY ADHERENCE ANALYSIS")
print("=" * 70)
print()

for run in ALL_RUNS:
    if run['returncode'] != 0:
        continue
    
    out_dir = run['out_dir']
    emotion = run['emotion']
    key = run.get('key')  # Only for scratch model
    
    # Skip if directory doesn't exist
    if not os.path.exists(out_dir):
        continue
    
    print(f"Analyzing: {os.path.basename(out_dir)}")
    
    try:
        results = compute_emotion_key_adherence(out_dir, emotion, key)
        
        EMOTION_KEY_REPORTS.append({
            'run': run,
            'emotion_adherence': results.get('emotion', {}),
            'key_adherence': results.get('key', {}) if key else None,
            'num_files': results.get('num_files', 0)
        })
        
        # Print summary
        if 'emotion' in results and 'adherence_ratio' in results['emotion']:
            emo_adh = results['emotion']['adherence_ratio'] * 100
            print(f"  Emotion adherence: {emo_adh:.1f}% ({results['emotion']['matches']}/{results['emotion']['total']})")
        
        if key and 'key' in results and 'adherence_ratio' in results['key']:
            key_adh = results['key']['adherence_ratio'] * 100
            print(f"  Key adherence: {key_adh:.1f}% ({results['key']['matches']}/{results['key']['total']})")
            if 'key_distribution' in results['key']:
                print(f"  Key distribution: {results['key']['key_distribution']}")
        
    except Exception as e:
        print(f"  [ERROR] {e}")
        continue

print(f"\nAnalyzed emotion/key for {len(EMOTION_KEY_REPORTS)} runs")
print()
# Out:
# ======================================================================
# ADHERENCE ANALYSIS (with distance metrics)
# ======================================================================
#
# Analyzed token adherence for 128 successful runs
#
# ======================================================================
# EMOTION AND KEY ADHERENCE ANALYSIS
# ======================================================================
#
# Analyzing: scratch_inference-deterministic_duration_emo1_keyAmaj_dur1080_20251103-0601416989
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-primed_duration_emo1_keyAmaj_dur1080_20251103-0602057929
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo1_keyAmaj_dur1080_20251103-0602219801
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo1_keyCmaj_dur1080_20251103-0603274911
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-primed_duration_emo1_keyCmaj_dur1080_20251103-0603397479
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-forced_duration_emo1_keyCmaj_dur1080_20251103-0603485553
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo1_keyEmin_dur1080_20251103-0604542479
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-primed_duration_emo1_keyEmin_dur1080_20251103-0605043473
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-forced_duration_emo1_keyEmin_dur1080_20251103-0605183865
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'F:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo2_keyAmaj_dur1080_20251103-0606237108
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo2_keyAmaj_dur1080_20251103-0606431778
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'F:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo2_keyAmaj_dur1080_20251103-0606576747
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'F:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo2_keyCmaj_dur1080_20251103-0608024449
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo2_keyCmaj_dur1080_20251103-0608259738
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo2_keyCmaj_dur1080_20251103-0608353401
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:min': 1}
# Analyzing: scratch_inference-deterministic_duration_emo2_keyEmin_dur1080_20251103-0609399410
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-primed_duration_emo2_keyEmin_dur1080_20251103-0610102663
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-forced_duration_emo2_keyEmin_dur1080_20251103-0610212323
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo3_keyAmaj_dur1080_20251103-0611263828
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo3_keyAmaj_dur1080_20251103-0611383826
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo3_keyAmaj_dur1080_20251103-0611476882
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo3_keyCmaj_dur1080_20251103-0612523604
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-primed_duration_emo3_keyCmaj_dur1080_20251103-0612598205
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-forced_duration_emo3_keyCmaj_dur1080_20251103-0613085035
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo3_keyEmin_dur1080_20251103-0614132467
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-primed_duration_emo3_keyEmin_dur1080_20251103-0614235308
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-forced_duration_emo3_keyEmin_dur1080_20251103-0614473307
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'F:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo4_keyAmaj_dur1080_20251103-0615522920
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo4_keyAmaj_dur1080_20251103-0616011729
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-forced_duration_emo4_keyAmaj_dur1080_20251103-0616094229
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo4_keyCmaj_dur1080_20251103-0617141736
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo4_keyCmaj_dur1080_20251103-0617198559
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-forced_duration_emo4_keyCmaj_dur1080_20251103-0617266310
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo4_keyEmin_dur1080_20251103-0618313188
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-primed_duration_emo4_keyEmin_dur1080_20251103-0618488523
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-forced_duration_emo4_keyEmin_dur1080_20251103-0618570317
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-deterministic_duration_emo1_keyAmaj_dur1920_20251103-0620017430
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo1_keyAmaj_dur1920_20251103-0620127171
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo1_keyAmaj_dur1920_20251103-0620221058
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo1_keyCmaj_dur1920_20251103-0621267005
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo1_keyCmaj_dur1920_20251103-0621368806
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo1_keyCmaj_dur1920_20251103-0621493918
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo1_keyEmin_dur1920_20251103-0622541488
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo1_keyEmin_dur1920_20251103-0623073875
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo1_keyEmin_dur1920_20251103-0623185338
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo2_keyAmaj_dur1920_20251103-0624234535
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo2_keyAmaj_dur1920_20251103-0624331904
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo2_keyAmaj_dur1920_20251103-0624447896
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo2_keyCmaj_dur1920_20251103-0625495185
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-primed_duration_emo2_keyCmaj_dur1920_20251103-0626543237
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-forced_duration_emo2_keyCmaj_dur1920_20251103-0627022621
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo2_keyEmin_dur1920_20251103-0628069535
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-primed_duration_emo2_keyEmin_dur1920_20251103-0628199926
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo2_keyEmin_dur1920_20251103-0628281866
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo3_keyAmaj_dur1920_20251103-0629328233
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo3_keyAmaj_dur1920_20251103-0629401822
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo3_keyAmaj_dur1920_20251103-0629515606
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo3_keyCmaj_dur1920_20251103-0630562859
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-primed_duration_emo3_keyCmaj_dur1920_20251103-0631051430
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo3_keyCmaj_dur1920_20251103-0631109897
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo3_keyEmin_dur1920_20251103-0632156381
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'G:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo3_keyEmin_dur1920_20251103-0632218087
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo3_keyEmin_dur1920_20251103-0632290686
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo4_keyAmaj_dur1920_20251103-0633337547
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo4_keyAmaj_dur1920_20251103-0633416357
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo4_keyAmaj_dur1920_20251103-0633505251
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo4_keyCmaj_dur1920_20251103-0634551085
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo4_keyCmaj_dur1920_20251103-0635030745
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo4_keyCmaj_dur1920_20251103-0635130666
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_duration_emo4_keyEmin_dur1920_20251103-0636178016
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'G#:maj': 1}
# Analyzing: scratch_inference-primed_duration_emo4_keyEmin_dur1920_20251103-0636249502
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_duration_emo4_keyEmin_dur1920_20251103-0636376856
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo1_keyAmaj_vel100_20251103-0637423051
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo1_keyAmaj_vel100_20251103-0638122049
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo1_keyAmaj_vel100_20251103-0638219809
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo1_keyCmaj_vel100_20251103-0639265763
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo1_keyCmaj_vel100_20251103-0639394508
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo1_keyCmaj_vel100_20251103-0639527412
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'G:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo1_keyEmin_vel100_20251103-0640573198
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'G:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo1_keyEmin_vel100_20251103-0641075566
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo1_keyEmin_vel100_20251103-0641207004
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo2_keyAmaj_vel100_20251103-0642254191
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo2_keyAmaj_vel100_20251103-0642412047
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-forced_velocity_emo2_keyAmaj_vel100_20251103-0642498449
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo2_keyCmaj_vel100_20251103-0643544025
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo2_keyCmaj_vel100_20251103-0644126897
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-forced_velocity_emo2_keyCmaj_vel100_20251103-0644216678
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo2_keyEmin_vel100_20251103-0645264550
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo2_keyEmin_vel100_20251103-0645390870
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo2_keyEmin_vel100_20251103-0645551845
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo3_keyAmaj_vel100_20251103-0646598607
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo3_keyAmaj_vel100_20251103-0647076520
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo3_keyAmaj_vel100_20251103-0647157276
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo3_keyCmaj_vel100_20251103-0648207425
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo3_keyCmaj_vel100_20251103-0648294903
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'C:min': 1}
# Analyzing: scratch_inference-forced_velocity_emo3_keyCmaj_vel100_20251103-0648353356
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo3_keyEmin_vel100_20251103-0649399068
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'G:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo3_keyEmin_vel100_20251103-0649588862
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo3_keyEmin_vel100_20251103-0650086673
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'G:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo4_keyAmaj_vel100_20251103-0651133516
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo4_keyAmaj_vel100_20251103-0651202837
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo4_keyAmaj_vel100_20251103-0651272428
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo4_keyCmaj_vel100_20251103-0652318352
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'F:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo4_keyCmaj_vel100_20251103-0652409883
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo4_keyCmaj_vel100_20251103-0652481704
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo4_keyEmin_vel100_20251103-0653529190
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-primed_velocity_emo4_keyEmin_vel100_20251103-0654028613
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo4_keyEmin_vel100_20251103-0654101666
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'G:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo1_keyAmaj_vel60_20251103-0655159687
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo1_keyAmaj_vel60_20251103-0655321770
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo1_keyAmaj_vel60_20251103-0655443226
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'F:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo1_keyCmaj_vel60_20251103-0656488816
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo1_keyCmaj_vel60_20251103-0656583318
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo1_keyCmaj_vel60_20251103-0657070397
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo1_keyEmin_vel60_20251103-0658116664
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo1_keyEmin_vel60_20251103-0658237950
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo1_keyEmin_vel60_20251103-0658319212
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo2_keyAmaj_vel60_20251103-0659366095
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-primed_velocity_emo2_keyAmaj_vel60_20251103-0700185892
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'B:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo2_keyAmaj_vel60_20251103-0700310927
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D#:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo2_keyCmaj_vel60_20251103-0701357996
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo2_keyCmaj_vel60_20251103-0701495965
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo2_keyCmaj_vel60_20251103-0702007217
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'B:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo2_keyEmin_vel60_20251103-0703053078
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo2_keyEmin_vel60_20251103-0703159969
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-forced_velocity_emo2_keyEmin_vel60_20251103-0703265074
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo3_keyAmaj_vel60_20251103-0704311062
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo3_keyAmaj_vel60_20251103-0704422161
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo3_keyAmaj_vel60_20251103-0704535346
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo3_keyCmaj_vel60_20251103-0705582432
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-primed_velocity_emo3_keyCmaj_vel60_20251103-0706072779
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo3_keyCmaj_vel60_20251103-0706158749
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:min': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo3_keyEmin_vel60_20251103-0707206143
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-primed_velocity_emo3_keyEmin_vel60_20251103-0707284792
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-forced_velocity_emo3_keyEmin_vel60_20251103-0707410943
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo4_keyAmaj_vel60_20251103-0708457519
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo4_keyAmaj_vel60_20251103-0708527124
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: scratch_inference-forced_velocity_emo4_keyAmaj_vel60_20251103-0709017902
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'D:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo4_keyCmaj_vel60_20251103-0710071826
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 100.0% (1/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo4_keyCmaj_vel60_20251103-0710153006
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:min': 1}
# Analyzing: scratch_inference-forced_velocity_emo4_keyCmaj_vel60_20251103-0710253369
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:maj': 1}
# Analyzing: scratch_inference-deterministic_velocity_emo4_keyEmin_vel60_20251103-0711303032
#   Emotion adherence: 100.0% (1/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'C:maj': 1}
# Analyzing: scratch_inference-primed_velocity_emo4_keyEmin_vel60_20251103-0711401725
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'A:min': 1}
# Analyzing: scratch_inference-forced_velocity_emo4_keyEmin_vel60_20251103-0711523821
#   Emotion adherence: 0.0% (0/1)
#   Key adherence: 0.0% (0/1)
#   Key distribution: {'E:maj': 1}
# Analyzing: pretrained_inference-deterministic_duration_emo1_dur1080_20251103-0712571868
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-primed_duration_emo1_dur1080_20251103-0713059805
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_duration_emo1_dur1080_20251103-0713156747
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_duration_emo2_dur1080_20251103-0713380980
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-primed_duration_emo2_dur1080_20251103-0713461710
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-forced_duration_emo2_dur1080_20251103-0713542290
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_duration_emo3_dur1080_20251103-0714127370
# Analyzing: pretrained_inference-primed_duration_emo3_dur1080_20251103-0715172999
# Analyzing: pretrained_inference-forced_duration_emo3_dur1080_20251103-0716219638
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_duration_emo4_dur1080_20251103-0716459004
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-primed_duration_emo4_dur1080_20251103-0716545680
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_duration_emo4_dur1080_20251103-0717036588
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_duration_emo1_dur1920_20251103-0717200227
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-primed_duration_emo1_dur1920_20251103-0717310872
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_duration_emo1_dur1920_20251103-0717390723
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-deterministic_duration_emo2_dur1920_20251103-0717471018
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-primed_duration_emo2_dur1920_20251103-0717593143
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-forced_duration_emo2_dur1920_20251103-0718149745
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-deterministic_duration_emo3_dur1920_20251103-0718252205
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-primed_duration_emo3_dur1920_20251103-0718325020
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_duration_emo3_dur1920_20251103-0718409882
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-deterministic_duration_emo4_dur1920_20251103-0718499348
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-primed_duration_emo4_dur1920_20251103-0718574448
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_duration_emo4_dur1920_20251103-0719081130
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_velocity_emo1_vel100_20251103-0719168806
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-primed_velocity_emo1_vel100_20251103-0719301240
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_velocity_emo1_vel100_20251103-0719390098
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_velocity_emo2_vel100_20251103-0720062052
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-primed_velocity_emo2_vel100_20251103-0720157412
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-forced_velocity_emo2_vel100_20251103-0720261025
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-deterministic_velocity_emo3_vel100_20251103-0720504176
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-primed_velocity_emo3_vel100_20251103-0721006665
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_velocity_emo3_vel100_20251103-0721112765
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_velocity_emo4_vel100_20251103-0721261527
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-primed_velocity_emo4_vel100_20251103-0721344612
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_velocity_emo4_vel100_20251103-0721422517
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_velocity_emo1_vel58_20251103-0722061054
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-primed_velocity_emo1_vel58_20251103-0722151821
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_velocity_emo1_vel58_20251103-0722226269
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_velocity_emo2_vel58_20251103-0722362818
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-primed_velocity_emo2_vel58_20251103-0722448418
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_velocity_emo2_vel58_20251103-0722529343
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-deterministic_velocity_emo3_vel58_20251103-0723012414
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-primed_velocity_emo3_vel58_20251103-0723103175
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_velocity_emo3_vel58_20251103-0723205511
#   Emotion adherence: 100.0% (1/1)
# Analyzing: pretrained_inference-deterministic_velocity_emo4_vel58_20251103-0723299172
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-primed_velocity_emo4_vel58_20251103-0723384544
#   Emotion adherence: 0.0% (0/1)
# Analyzing: pretrained_inference-forced_velocity_emo4_vel58_20251103-0723488408
#   Emotion adherence: 0.0% (0/1)
#
# Analyzed emotion/key for 192 runs

# %%
# Tiempo de fin
adherence_analysis_end_time = time.time()
print(f"Tiempo total de análisis de adherencia: {adherence_analysis_end_time - adherence_analysis_start_time:.2f} segundos")
# Out:
# Tiempo total de análisis de adherencia: 4177.34 segundos

# %% [markdown]
# ## AGGREGATE RESULTS

# %%
# ============================================================================
# AGGREGATE RESULTS
# ============================================================================

print("=" * 70)
print("AGGREGATING RESULTS: COMPARISON ACROSS INFERENCE MODES")
print("=" * 70)
print()

# Aggregate by (model, mode, emotion, key_tag, token_subset)
agg = defaultdict(lambda: defaultdict(lambda: {'adherence': [], 'distance': []}))
emotion_key_agg = defaultdict(lambda: {'emotion_adherence': [], 'key_adherence': [], 'key_correlation': []})

# Aggregate token adherence
for report in REPORTS:
    run = report['run']
    key = (run['model'], run['mode'], run['emotion'], run.get('key'), tuple(run['subset']))
    
    # Average per file, then accumulate
    for f in report['files']:
        for token_name, stats in f['adherence'].items():
            agg[key][token_name]['adherence'].append(stats['adherence_ratio'])
            if stats.get('is_numeric') and 'mean_distance' in stats:
                agg[key][token_name]['distance'].append(stats['mean_distance'])

# Aggregate emotion/key adherence
for report in EMOTION_KEY_REPORTS:
    run = report['run']
    key = (run['model'], run['mode'], run['emotion'], run.get('key'), tuple(run['subset']))
    
    if 'emotion_adherence' in report and isinstance(report['emotion_adherence'], dict):
        if 'adherence_ratio' in report['emotion_adherence']:
            emotion_key_agg[key]['emotion_adherence'].append(report['emotion_adherence']['adherence_ratio'])
    
    if report.get('key_adherence') and isinstance(report['key_adherence'], dict):
        if 'adherence_ratio' in report['key_adherence']:
            emotion_key_agg[key]['key_adherence'].append(report['key_adherence']['adherence_ratio'])
        if 'mean_correlation' in report['key_adherence']:
            emotion_key_agg[key]['key_correlation'].append(report['key_adherence']['mean_correlation'])

# Compute final statistics
# Include entries from both token adherence (agg) and emotion/key adherence (emotion_key_agg)
# This ensures forced mode entries are included (with only emotion/key metrics)
all_keys = set(agg.keys()) | set(emotion_key_agg.keys())

final_results = []
for key in all_keys:
    model, mode, emotion, key_tag, subset = key
    row = {
        'model': model,
        'mode': mode,
        'emotion': emotion,
        'key': key_tag,
        'subset': list(subset),
    }
    
    # Add token adherence metrics (if available - not present for forced mode)
    if key in agg:
        token_stats = agg[key]
        for token_name, metrics in token_stats.items():
            if metrics['adherence']:
                row[f'{token_name}_adherence'] = float(np.mean(metrics['adherence']))
            if metrics['distance']:
                row[f'{token_name}_distance'] = float(np.mean(metrics['distance']))
    
    # Add emotion/key adherence if available
    if key in emotion_key_agg:
        ek_metrics = emotion_key_agg[key]
        if ek_metrics['emotion_adherence']:
            row['emotion_adherence'] = float(np.mean(ek_metrics['emotion_adherence']))
        if ek_metrics['key_adherence']:
            row['key_adherence'] = float(np.mean(ek_metrics['key_adherence']))
        if ek_metrics['key_correlation']:
            row['key_correlation'] = float(np.mean(ek_metrics['key_correlation']))
    
    final_results.append(row)

# Save results
results_file = EXP / 'evaluation_results_comprehensive.json'
with open(results_file, 'w', encoding='utf-8') as f:
    json.dump(final_results, f, indent=2)

print(f"Results saved to: {results_file}")
print(f"Total result rows: {len(final_results)}")
print()
# Out:
# ======================================================================
# AGGREGATING RESULTS: COMPARISON ACROSS INFERENCE MODES
# ======================================================================
#
# Results saved to: S:\UVG\LOCKIN\emotune\workspace\exp\eval_run_v7_01\evaluation_results_comprehensive.json
# Total result rows: 96

# %% [markdown]
# ## DISPLAY RESULTS: COMPARISON TABLE

# %%
print("=" * 90)
print("ADHERENCE COMPARISON BY MODE (Average across emotions and conditions)")
print("=" * 90)
print()

# Group by (model, mode) and average everything else
mode_comparison = defaultdict(lambda: defaultdict(lambda: {'adherence': [], 'distance': []}))

for row in final_results:
    key = (row['model'], row['mode'])
    for k, v in row.items():
        if k.endswith('_adherence'):
            token = k.replace('_adherence', '')
            mode_comparison[key][token]['adherence'].append(v)
        elif k.endswith('_distance'):
            token = k.replace('_distance', '')
            mode_comparison[key][token]['distance'].append(v)
        elif k == 'key_correlation':
            # Store correlation as a "distance" metric for key (higher = better)
            mode_comparison[key]['key']['distance'].append(v)

# Print comparison table
all_tokens = TOKENS_OF_INTEREST + ['emotion', 'key']

for model_name in [m['name'] for m in MODELS]:
    print(f"{'─' * 90}")
    print(f"Model: {model_name.upper()}")
    print(f"{'─' * 90}")
    print(f"{'Mode':26s} | {'Token':10s} | {'Adherence %':12s} | {'Avg Distance':12s}")
    print(f"{'-' * 90}")
    
    for mode in MODES:
        key = (model_name, mode)
        if key not in mode_comparison:
            continue
        
        first = True
        for token in all_tokens:
            if token not in mode_comparison[key]:
                continue
            
            metrics = mode_comparison[key][token]
            adherence_pct = np.mean(metrics['adherence']) * 100 if metrics['adherence'] else 0.0
            distance = np.mean(metrics['distance']) if metrics['distance'] else None
            
            # Skip key for pretrained model
            if token == 'key' and model_name == 'pretrained':
                continue
            
            mode_str = mode if first else ''
            # For key, distance is correlation (higher = better), for others it's actual distance (lower = better)
            if token == 'key' and distance is not None:
                distance_str = f"{distance:.4f} ↑"  # Arrow indicates higher is better
            elif distance is not None:
                distance_str = f"{distance:.2f}"
            else:
                distance_str = 'N/A'
            
            print(f"{mode_str:26s} | {token:10s} | {adherence_pct:11.2f}% | {distance_str:>12s}")
            first = False
        
        if not first:  # Add separator between modes
            print()

print("=" * 90)
print()
# Out:
# ==========================================================================================
# ADHERENCE COMPARISON BY MODE (Average across emotions and conditions)
# ==========================================================================================
#
# ──────────────────────────────────────────────────────────────────────────────────────────
# Model: SCRATCH
# ──────────────────────────────────────────────────────────────────────────────────────────
# Mode                       | Token      | Adherence %  | Avg Distance
# ------------------------------------------------------------------------------------------
# inference-deterministic    | duration   |        8.05% |       677.59
#                            | velocity   |        1.36% |        23.52
#                            | emotion    |       45.83% |          N/A
#                            | key        |       41.67% |     0.7444 ↑
#
# inference-primed           | duration   |        7.14% |       762.87
#                            | velocity   |        1.78% |        25.52
#                            | emotion    |       35.42% |          N/A
#                            | key        |       33.33% |     0.7556 ↑
#
# inference-forced           | emotion    |       25.00% |          N/A
#                            | key        |        8.33% |     0.5594 ↑
#
# ──────────────────────────────────────────────────────────────────────────────────────────
# Model: PRETRAINED
# ──────────────────────────────────────────────────────────────────────────────────────────
# Mode                       | Token      | Adherence %  | Avg Distance
# ------------------------------------------------------------------------------------------
# inference-deterministic    | duration   |        9.37% |       567.56
#                            | velocity   |        7.20% |        10.74
#                            | emotion    |       50.00% |          N/A
#
# inference-primed           | duration   |        3.15% |       811.88
#                            | velocity   |        2.72% |        18.82
#                            | emotion    |       18.75% |          N/A
#
# inference-forced           | emotion    |       31.25% |          N/A
#
# ==========================================================================================
